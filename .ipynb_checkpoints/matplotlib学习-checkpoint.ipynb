# %% [markdown]
# 参考：
# https://jakevdp.github.io/PythonDataScienceHandbook/

# %% [markdown]
# # 数据可视化的用途
# - 探索数据
# - 交流数据
# ## 绘图步骤
# 1. 给定轴数据
# 2. 给轴标记
# 3. 给图标题
# 4. 展示图像
#
# # 常用方法
# 1. plot(*args, **kwargs)用于绘制线或者点
# 2. title(s, *args, **kwargs)为当前坐标系设置标题
# 3. show(*args, **kw)展示图片
# 4. xlabel(s, *args, **kwargs) 设置x轴标签
# 5. ylabel(s, *args, **kwargs)设置y轴标签
# 6. bar(*args, **kwargs)绘制条形图
# 7. scatter(x, y[, s, c, marker, cmap, norm, …])绘制散点图
# 8. xticks(*args, **kwargs)为x轴的位置设置标记
# 9. yticks(*args, **kwargs)为y轴位置设置标记
# [https://matplotlib.org/api/_as_gen/matplotlib.pyplot.html]

# %% [markdown]
# # Figure和Subplot
# - matplotlib的图像都位于Figure对象中。你可以用plt.figure创建一个新的Figure：
# - 不能通过空Figure绘图。必须用add_subplot创建一个或多个subplot子图才行：
# figure (an instance of the class plt.Figure) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels.
#
# The axes (an instance of the class plt.Axes) is what we see above: a bounding box with ticks and labels, which will eventually contain the plot elements that make up our visualization.

# %% [markdown]
# # matplotlib通用技巧

# %%
# 1. 导入
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# 2. 设置风格
plt.style.use('classic')

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # 线性图
# 通过plot可以创建一个图和坐标
# - plot([x], y, [fmt], data=None, **kwargs)
# - plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# [https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
# 创建一张图
fig = plt.figure()
# 创建一个坐标
ax = plt.axes()

x = np.arange(0, 5, 0.1)  #绘制50个点
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# ## 调整线的颜色和风格

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# # 条形图
# - bar(x, height, *, align='center', **kwargs)
# - bar(x, height, width, *, align='center', **kwargs)
# - bar(x, height, width, bottom, *, align='center', **kwargs)
# [https://matplotlib.org/api/_as_gen/matplotlib.pyplot.bar.html#matplotlib.pyplot.bar]

# %%
import math

def bucketize(point, bucket_size):
    
    return bucket_size * math.floor(point/bucket_size)

def make_hisogram(points, bucket_size):
    
    return

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.arange(10)
fig = plt.plot(data)

# %% [markdown]
# # 直方图

# %%
data = np.random.randn(1000)
plt.hist(data);

# %%
plt.hist(data, bins=30, normed=True, alpha=0.5,
         histtype='stepfilled', color='steelblue', edgecolor='none')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([0.00496062, 0.        , 0.00496062, 0.01984248, 0.03968496,
#         0.05456683, 0.11409427, 0.07936993, 0.17858234, 0.17362172,
#         0.21330668, 0.26787351, 0.32740096, 0.39684964, 0.49606205,
#         0.44645585, 0.3869284 , 0.3621253 , 0.26787351, 0.27779475,
#         0.21330668, 0.13393675, 0.22322792, 0.07936993, 0.06944869,
#         0.06448807, 0.02976372, 0.01984248, 0.00992124, 0.00496062]),
#  array([-3.09592364, -2.89433596, -2.69274828, -2.49116059, -2.28957291,
#         -2.08798523, -1.88639754, -1.68480986, -1.48322218, -1.2816345 ,
#         -1.08004681, -0.87845913, -0.67687145, -0.47528376, -0.27369608,
#         -0.0721084 ,  0.12947928,  0.33106697,  0.53265465,  0.73424233,
#          0.93583002,  1.1374177 ,  1.33900538,  1.54059306,  1.74218075,
#          1.94376843,  2.14535611,  2.34694379,  2.54853148,  2.75011916,
#          2.95170684]),
#  <a list of 1 Patch objects>)

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([0.00290833, 0.        , 0.00290833, 0.        , 0.00290833,
#         0.008725  , 0.00290833, 0.01163334, 0.02326668, 0.01745001,
#         0.01454167, 0.06398337, 0.06980004, 0.06980004, 0.10179172,
#         0.12796673, 0.10470005, 0.13087507, 0.15705008, 0.20940011,
#         0.22685012, 0.18031676, 0.17740842, 0.16577509, 0.17159175,
#         0.14250841, 0.13669174, 0.12796673, 0.12215006, 0.09888338,
#         0.05235003, 0.07561671, 0.04071669, 0.02326668, 0.02035834,
#         0.008725  , 0.00581667, 0.00290833, 0.00290833, 0.00290833]),
#  array([-4.49631408, -4.15247471, -3.80863535, -3.46479598, -3.12095662,
#         -2.77711725, -2.43327789, -2.08943852, -1.74559916, -1.40175979,
#         -1.05792043, -0.71408106, -0.3702417 , -0.02640233,  0.31743703,
#          0.6612764 ,  1.00511576,  1.34895513,  1.69279449,  2.03663386,
#          2.38047322,  2.72431259,  3.06815195,  3.41199132,  3.75583068,
#          4.09967005,  4.44350941,  4.78734878,  5.13118814,  5.47502751,
#          5.81886688,  6.16270624,  6.50654561,  6.85038497,  7.19422434,
#          7.5380637 ,  7.88190307,  8.22574243,  8.5695818 ,  8.91342116,
#          9.25726053]),
#  <a list of 1 Patch objects>)

# %% [markdown]
# # 散点图
# - scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, hold=None, data=None, **kwargs)[source]
# [https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter]

# %%
x = np.linspace(0, 12, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black')

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker, label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8)
# Out:
# (0, 1.8)

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# # 误差图

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0);

# %%
from sklearn.gaussian_process import GaussianProcess

# define the model and draw some data
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)

# Compute the Gaussian process fit
gp = GaussianProcess(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1E-1,
                     random_start=100)
gp.fit(xdata[:, np.newaxis], ydata)

xfit = np.linspace(0, 10, 1000)
yfit, MSE = gp.predict(xfit[:, np.newaxis], eval_MSE=True)
dyfit = 2 * np.sqrt(MSE)  # 2*sigma ~ 95% confidence region
# Visualize the result
plt.plot(xdata, ydata, 'or')
plt.plot(xfit, yfit, '-', color='gray')

plt.fill_between(xfit, yfit - dyfit, yfit + dyfit,
                 color='gray', alpha=0.2)
plt.xlim(0, 10);

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
plt.contour(X, Y, Z, colors='black');

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');

# %% [markdown]
# 默认绘图位置为最后一个子图

# %%
 plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
# Out:
# (array([ 1.,  0.,  1.,  2.,  1.,  7.,  3.,  7.,  7., 11.,  4., 15., 10.,
#          7.,  9.,  9.,  4.,  0.,  1.,  1.]),
#  array([-3.02535301, -2.74358567, -2.46181833, -2.18005099, -1.89828365,
#         -1.61651631, -1.33474897, -1.05298163, -0.77121429, -0.48944695,
#         -0.20767961,  0.07408773,  0.35585507,  0.63762241,  0.91938975,
#          1.20115709,  1.48292443,  1.76469177,  2.04645911,  2.32822645,
#          2.60999379]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
 fig, axes = plt.subplots(2, 3)
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">

# %% [markdown]
# 创建多个子图，返回numpy数组

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009E6E1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009EB5DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009EE44A8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009F0BB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009F40240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000009F66358>]],
#       dtype=object)

# %%
axes[1][0]

# %% [markdown]
# ### 调整subplot(子图)周围的间距
# subplots_adjust(left=None, bottom=None, right=None, top=None,
#                 wspace=None, hspace=None)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0.1)
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# ### 颜色、标记和线型

# %%
from numpy.random import randn
fig = plt.figure()
plt.plot(randn(30).cumsum(), 'ko--')
plt.plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">

# %% [markdown]
# ### 刻度、标签和图例

# %% [markdown]
# ### 设置标题、轴标签、刻度以及刻度标签

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax = plt.plot(np.random.randn(1000).cumsum())
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">

# %%
ax.set_title('My first matplotlib plot')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-9cc2dcf58ca9> in <module>()
# ----> 1 ax.set_title('My first matplotlib plot')
#
# AttributeError: 'list' object has no attribute 'set_title'

# %% [markdown]
# ##  添加图例

# %%
import numpy as np
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')
ax.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">

# %% [markdown]
# ### 将图表保存到文件

# %%
plt.savefig('figpath.svg')

# %% [markdown]
# # pandas绘图

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure()

# %%
fig.suptitle('no axes on this figure')
# Out:
# Text(0.5,0.98,'no axes on this figure')

# %%
fig, ax_lst = plt.subplots(2, 2)

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('simple plot')
plt.legend()
plt.show()

# %%
x = np.arange(0, 10, 0.2)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
x = np.linspace(0,20)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)
plt.figure()

# %%
plt.plot(x, y1)
plt.plot(x, y2)

# %%
plt.plot(x,
     y1,
     color='black',
     linestyle='-',
     linewidth=2,
     marker='s',
     markersize=6,
     label='y1')
plt.xlabel('x')
plt.ylabel('y')
plt.title('sin')
plt.legend()

# %%
fig = plt.Figure()
ax = plt.axes()

# %%
fig = plt.Figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x), color='blue', linestyle='dashed')
plt.plot(x, np.cos(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x, np.sin(x), color='blue', linestyle='dashed')
plt.plot(x, np.cos(x))
plt.xlim(10, 1)
plt.ylim(1.5, -1.5)
# Out:
# (1.5, -1.5)
